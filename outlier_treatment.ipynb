# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('cleaned.csv')

# %%
df.shape
# Out:
# (3803, 23)

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# ...

# %%
#outliers on price
sns.distplot(df['price'])
#this is left skewed
# Out:
# C:\Users\Hardik\AppData\Local\Temp\ipykernel_16292\455821140.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
 #to deal with outiliers we will use iqr
q1 = df['price'].quantile(0.25)
q3 = df['price'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

#identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
print(f'Number of outliers: {outliers.shape[0]}')
outliers_price_stats = outliers['price'].describe()
print(outliers_price_stats)
# Out:
# Number of outliers: 432
# count    432.000000
# mean       9.196157
# std        4.061291
# min        5.350000
# 25%        6.400000
# 50%        8.000000
# 75%       10.607500
# max       31.500000
# Name: price, dtype: float64

# %%
sns.distplot(outliers['price_per_sqft'])
# Out:
# C:\Users\Hardik\AppData\Local\Temp\ipykernel_16292\3241912800.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(outliers['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
q1 = df['price_per_sqft'].quantile(0.25)
q3 = df['price_per_sqft'].quantile(0.75)

iqr = q3-q1

lower_bound = q1-1.5*iqr
upper_bound = q3+1.5*iqr

outlier_sqft = df[(df['price_per_sqft']<lower_bound) | (df['price_per_sqft']>upper_bound)]
outlier_sqft_stats = outlier_sqft['price_per_sqft'].describe()
print(outlier_sqft.shape,outlier_sqft_stats)
# Out:
# (367, 23) count       367.000000
# mean      52115.435967
# std       60746.225927
# min       24202.000000
# 25%       27778.000000
# 50%       33333.000000
# 75%       41790.000000
# max      600000.000000
# Name: price_per_sqft, dtype: float64

# %%
outlier_sqft['area'] = outlier_sqft['area'].apply(lambda x: x*9 if x < 1000 else x)

# %%
outlier_sqft['price_per_sqft'] = round((outlier_sqft['price']*10000000)/(outlier_sqft['area']))

# %%
outlier_sqft['price_per_sqft'].describe()
# Out:
# count      367.000000
# mean     29160.735695
# std      12308.413881
# min       2689.000000
# 25%      25051.500000
# 50%      29630.000000
# 75%      35489.000000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outlier_sqft)

# %%
sns.displot(df['price_per_sqft'],kde=True)

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
#these are the outliers which are still present in the data.
#which are kind of data problem
# Out:
#      property_type                       society      sector  price  \
# 386          house            cloudnine cottages  sohna road   5.50
# 671          house            emaar mgf marbella   sector 66  18.00
# 1200         house                   independent   sector 26  14.75
# 1261         house                   independent   sector 25  16.00
# 1349          flat                unitech vistas   sector 70   9.00
# 1425         house  project housing board colony   sector 31   8.00
# 1640         house        emaar the palm springs   sector 54  14.00
# 1839         house                unitech escape   sector 50  10.80
# 2211         house                   independent   sector 26  26.00
# 2290         house                  malibu towne   sector 47   8.50
# 2488         house                dlf city plots   sector 26  26.00
# 3046         house        emaar the palm springs   sector 54  24.00
# 3285         house                           nul   sector 28  12.50
#
# ...

# %%
df = df[df['price_per_sqft']<=50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# Aera

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Hardik\AppData\Local\Temp\ipykernel_16292\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3772.00000
# mean       2906.69035
# std       22822.30511
# min         145.00000
# 25%        1257.75000
# 50%        1745.00000
# 75%        2340.00000
# max      875000.00000
# Name: area, dtype: float64

# %%
df[df['area']>100000]
#according to thier area thier price is to less so it would be data issue
# Out:
#      property_type                    society      sector  price  \
# 1638          flat  signature global solera 2  sector 107   0.51
# 1648          flat          hcbs sports ville  sohna road   0.35
# 2111          flat      signature the roselia   sector 95   0.45
# 2651          flat            ramsons kshitij   sector 95   0.31
# 3021         house                independent   sector 50   5.00
#
#       price_per_sqft      area                           areaWithType  \
# 1638             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 1648             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 2111             7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 2651             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 3021           232.0  215517.0             Plot area 2(1011.71 sq.m.)
#
#       bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# 1638        2         2       1  ...                  NaN           NaN
# ...

# %%
df = df[df['price_per_sqft']<50000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Hardik\AppData\Local\Temp\ipykernel_16292\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
df[df['area']>10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 1648          flat          hcbs sports ville  sohna road   0.35
# 2111          flat      signature the roselia   sector 95   0.45
# 2651          flat            ramsons kshitij   sector 95   0.31
# 1638          flat  signature global solera 2  sector 107   0.51
# 3021         house                independent   sector 50   5.00
# 818          house                independent   sector 26  18.40
# 48           house  ganpati heights apartment   sector 13   1.25
# 1796          flat                 rof ananda   sector 95   0.38
# 1123          flat                 rof ananda   sector 95   0.38
# 300          house      dlf city plot phase 4   sector 28  13.00
# 2             flat              pyramid elite   sector 86   0.46
# 2356          flat                 rof ananda   sector 95   0.33
# 115           flat      signature the serenas  sohna road   0.28
# ...

# %%
df.drop(index=[2651,1638,3021,1648,2111,818, 1796, 1123, 2, 2356, 115, 3649, 2503, 1471], inplace=True)

# %%
df.loc[48,'area'] = 115*9
df.loc[300,'area'] = 7250
df.loc[2666,'area'] = 5800
df.loc[1358,'area'] = 2660
df.loc[3195,'area'] = 2850
df.loc[2131,'area'] = 1812
df.loc[3088,'area'] = 2160
df.loc[3444,'area'] = 1175

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Hardik\AppData\Local\Temp\ipykernel_16292\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(df['area'])
# Out:
# <Axes: ylabel='area'>

# %%
df['area'].describe()
# Out:
# count     3757.000000
# mean      1942.143998
# std       1213.779740
# min        145.000000
# 25%       1250.000000
# 50%       1742.000000
# 75%       2315.000000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# bedRoom

# %%
sns.displot(df['bedRoom'],kde=True)

# %%
sns.boxplot(df['bedRoom'])
# Out:
# <Axes: ylabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3757.000000
# mean        3.308491
# std         1.798522
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 3618         house                  independent   sector 54   5.00
# 2611         house                  independent   sector 43   4.50
# 78           house                  independent   sector 17   3.87
# 1493         house                  independent   sector 17   3.93
# 1381         house                private house   sector 55   7.05
# 19           house                  independent   sector 54   5.50
# 3457         house                  independent   sector 56  12.39
# 3698         house                  independent   sector 55   9.19
# 2137         house                  independent   sector 40  12.00
# 2096         house       luxury dlf city floors   sector 26  20.00
# 874          house               dlf city plots   sector 26  20.00
# 372          house                  independent   sector 11   4.50
# 2833         house                  independent   sector 24   3.20
# ...

# %%
df = df[df['bedRoom']<=10]

# %%
sns.boxplot(df['bedRoom'])
# Out:
# <Axes: ylabel='bedRoom'>

# %%
df.shape
# Out:
# (3713, 23)

# %% [markdown]
# Bathroom

# %%
sns.distplot(df['bathroom'],kde=True)
# Out:
# C:\Users\Hardik\AppData\Local\Temp\ipykernel_16292\706850268.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'],kde=True)
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(df['bathroom'])
# Out:
# <Axes: ylabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 3267         house  adani brahma samsara  sector 60  18.02         28200.0
# 2771         house           independent  sector 39   7.00         10000.0
# 2816         house           independent  sector 24  11.00         28902.0
#
#         area                                       areaWithType  bedRoom  \
# 3267  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 2771  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 2816  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  ...  super_built_up_area built_up_area carpet_area  \
# 3267        12      3+  ...                  NaN        6390.0         NaN
# 2771        11      3+  ...                  NaN        7000.0         NaN
# 2816        11      3+  ...                  NaN        5000.0         NaN
#
#       study room  servant room  store room  pooja room  others  \
# ...

# %% [markdown]
# super built up area

# %%
sns.distplot(df['super_built_up_area'],kde=True)
# Out:
# C:\Users\Hardik\AppData\Local\Temp\ipykernel_16292\2362885225.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'],kde=True)
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(df['super_built_up_area'], color='lightgreen')
# Out:
# <Axes: ylabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1915.000000
# mean      1921.658251
# std        767.160169
# min         89.000000
# 25%       1457.000000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 1323          flat  bestech park view grand spa    sector 81    4.7
# 3265          flat       krrish provence estate  gwal pahari    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 1323          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 3265          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# 1323        4         4      3+  ...               6926.0           NaN
# 3265        5         6      3+  ...              10000.0           NaN
#
#      carpet_area  study room  servant room  store room  pooja room  others  \
# 1323         NaN           0             1           0           0       0
# 3265         NaN           0             1           0           1       1
#
#       furnishing_type  luxury_score
# 1323                1           140
# ...

# %% [markdown]
# built up area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\Hardik\AppData\Local\Temp\ipykernel_16292\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 2834         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  ...  \
# 2834  Plot area 1254(1048.5 sq.m.)        6         7      3+  ...
#
#       super_built_up_area built_up_area carpet_area  study room  servant room  \
# 2834                  NaN       11286.0         NaN           1             1
#
#       store room  pooja room  others  furnishing_type  luxury_score
# 2834           0           1       1                1            42
#
# [1 rows x 23 columns]

# %% [markdown]
# carpet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\Hardik\AppData\Local\Temp\ipykernel_16292\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2131          flat      godrej air  sector 85    2.5          1379.0   1812.0
# 2342          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  ...  \
# 2131  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+  ...
# 2342  Carpet area: 11000 (1021.93 sq.m.)        4         4       3  ...
#
#       super_built_up_area built_up_area carpet_area  study room  servant room  \
# 2131                  NaN           NaN     18122.0           1             0
# 2342                  NaN           NaN     11000.0           0             1
#
#       store room  pooja room  others  furnishing_type  luxury_score
# 2131           0           1       1                1            44
# 2342           0           0       0                0            60
#
# [2 rows x 23 columns]

# %%
df.loc[2131,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2342          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  ...  \
# 2342  Carpet area: 11000 (1021.93 sq.m.)        4         4       3  ...
#
#       super_built_up_area built_up_area carpet_area  study room  servant room  \
# 2342                  NaN           NaN     11000.0           0             1
#
#       store room  pooja room  others  furnishing_type  luxury_score
# 2342           0           0       0                0            60
#
# [1 rows x 23 columns]

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
# 5          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7585.0  1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0  1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 3          5470.0   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0  1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
# 5          9022.0   532.0  Super Built up area 632(58.71 sq.m.)Carpet are...
#
#    bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# ...

# %% [markdown]
# luxury score

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\Hardik\AppData\Local\Temp\ipykernel_16292\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df.shape
# Out:
# (3713, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
# 5          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7586.0  1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8597.0  1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 3          5470.0   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0  1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
# 5          9023.0   532.0  Super Built up area 632(58.71 sq.m.)Carpet are...
#
#    bedRoom  bathroom balcony  ...  super_built_up_area built_up_area  \
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\Hardik\AppData\Local\Temp\ipykernel_16292\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 711          house                   independent   sector 26   20.0
# 901          house                   independent   sector 28   12.0
# 1090         house                   independent  sector 105    9.9
# 1509         house                   independent   sector 55    5.0
# 1526         house                dlf city plots   sector 26   19.0
# 2040         house                   independent   sector 43    9.5
# 2130         house                   independent   sector 26   19.0
# 3054         house  sushant lok 1 builder floors   sector 43   13.0
# 3108         house                   independent   sector 25   13.0
#
#       price_per_sqft    area  \
# 711          44444.0  4500.0
# 901          42194.0  2844.0
# 1090         49500.0  2000.0
# 1509         44444.0  1125.0
# 1526         42054.0  4518.0
# 2040         42222.0  2250.0
# 2130         42222.0  4500.0
# 3054         48148.0  2700.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# np.float64(257.0)

# %%
df[(df['area']/df['bedRoom'])<257]
# Out:
#      property_type                                 society      sector  price  \
# 9            house                             independent  sector 105   1.20
# 15           house                             independent   sector 12   1.20
# 37           house                             independent  sector 104   0.45
# 48           house               ganpati heights apartment   sector 13   1.25
# 74           house                             independent   sector 25   7.60
# ...            ...                                     ...         ...    ...
# 3722          flat                                 my home  sector 110   0.22
# 3738         house                             independent    sector 7   1.16
# 3751         house                             independent   sector 21   0.45
# 3774         house                             independent   sector 28   0.45
# 3797         house  surendra homes dayaindependentd colony    sector 6   0.75
#
#       price_per_sqft    area  \
# ...

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']
(df[df['area_room_ratio']<250])['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     48
# 3     35
# 5     28
# 6     17
# 4     17
# 9     15
# 8     12
# 10     8
# 7      8
# Name: count, dtype: int64

# %%
df = df[df['area_room_ratio']>100]

# %%
outliers_df = df[(df['area_room_ratio']<250) & (df['bedRoom']>3)]

# %%
outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])
#means ever floor have equal number of rooms

# %%
df.update(outliers_df)

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom']>4)]
# Out:
#      property_type               society      sector  price  price_per_sqft  \
# 93           house           independent  sector 105   1.10         12222.0
# 387          house           independent   sector 12   0.65          6500.0
# 753          house              shivpuri    sector 7   2.80         12444.0
# 1106         house           independent    sector 5   0.85          9444.0
# 1206         house           independent    sector 7   1.16         11717.0
# 1747         house           independent   sector 12   2.50         13889.0
# 1936         house           independent   sector 11   3.50         15556.0
# 1939         house           independent     manesar   1.10          6173.0
# 2806         house           independent    sector 2   0.98          9074.0
# 3148         house  bhim nagar, sector 6    sector 6   0.85         14096.0
# 3246         house           independent     manesar   0.80          6667.0
# ...

# %%
df = df[~((df['area_room_ratio'] < 250) & (df['bedRoom'] > 4))]

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df.to_csv('outlier_treated.csv',index=False)
